# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
api_keys = "faad48cb73dbdbbfa08cb7d1afe0c4c2"
#from api_keys import weather_api_key
# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

output_data_file = "Downloads/Starter_Code/output_data/cities.csv"

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\iandh\anaconda3\lib\site-packages (0.0.6)
# Requirement already satisfied: kdtree>=0.12 in c:\users\iandh\anaconda3\lib\site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 590

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID={api_keys}"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

         # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
       

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vodnyy
# Processing Record 2 of Set 1 | margaret river
# Processing Record 3 of Set 1 | iqaluit
# Processing Record 4 of Set 1 | walvis bay
# Processing Record 5 of Set 1 | tuy hoa
# Processing Record 6 of Set 1 | devinuwara
# City not found. Skipping...
# Processing Record 7 of Set 1 | udachny
# Processing Record 8 of Set 1 | bredasdorp
# Processing Record 9 of Set 1 | qaqortoq
# Processing Record 10 of Set 1 | saldanha
# Processing Record 11 of Set 1 | el bauga
# Processing Record 12 of Set 1 | port-aux-francais
# Processing Record 13 of Set 1 | ilulissat
# Processing Record 14 of Set 1 | bethel
# Processing Record 15 of Set 1 | urucurituba
# Processing Record 16 of Set 1 | grytviken
# Processing Record 17 of Set 1 | adamstown
# Processing Record 18 of Set 1 | port elizabeth
# Processing Record 19 of Set 1 | hermanus
# Processing Record 20 of Set 1 | dudinka
# Processing Record 21 of Set 1 | jamestown
# Processing Record 22 of Set 1 | yellowknife
# Processing Record 23 of Set 1 | rimavska sobota
# Processing Record 24 of Set 1 | coquimbo
# Processing Record 25 of Set 1 | middelburg
# Processing Record 26 of Set 1 | cumana
# Processing Record 27 of Set 1 | sao paulo de olivenca
# Processing Record 28 of Set 1 | ancud
# Processing Record 29 of Set 1 | acarau
# Processing Record 30 of Set 1 | remire-montjoly
# Processing Record 31 of Set 1 | labytnangi
# Processing Record 32 of Set 1 | sitka
# Processing Record 33 of Set 1 | punta gorda
# Processing Record 34 of Set 1 | avarua
# Processing Record 35 of Set 1 | huarmey
# Processing Record 36 of Set 1 | raduzhny
# Processing Record 37 of Set 1 | mejit
# Processing Record 38 of Set 1 | ushuaia
# Processing Record 39 of Set 1 | albany
# Processing Record 40 of Set 1 | codrington
# Processing Record 41 of Set 1 | alofi
# Processing Record 42 of Set 1 | ha giang
# Processing Record 43 of Set 1 | kavaratti
# Processing Record 44 of Set 1 | baukau
# Processing Record 45 of Set 1 | georgetown
# Processing Record 46 of Set 1 | olonkinbyen
# Processing Record 47 of Set 1 | ljusdal
# Processing Record 48 of Set 1 | malango
# Processing Record 49 of Set 1 | nikolayevsk-on-amure
# Processing Record 50 of Set 1 | fisterra
# Processing Record 0 of Set 2 | blackmans bay
# Processing Record 1 of Set 2 | stanley
# Processing Record 2 of Set 2 | klyuchi
# Processing Record 3 of Set 2 | praia da vitoria
# Processing Record 4 of Set 2 | bermeo
# Processing Record 5 of Set 2 | badger
# Processing Record 6 of Set 2 | timimoun
# Processing Record 7 of Set 2 | beichengqu
# Processing Record 8 of Set 2 | dunedin
# Processing Record 9 of Set 2 | akureyri
# Processing Record 10 of Set 2 | sao luis
# Processing Record 11 of Set 2 | hawaiian paradise park
# Processing Record 12 of Set 2 | otjiwarongo
# Processing Record 13 of Set 2 | santiago de cao
# Processing Record 14 of Set 2 | orsa
# Processing Record 15 of Set 2 | pimentel
# Processing Record 16 of Set 2 | talnakh
# Processing Record 17 of Set 2 | invercargill
# Processing Record 18 of Set 2 | isafjordur
# Processing Record 19 of Set 2 | jinchang
# Processing Record 20 of Set 2 | nguigmi
# Processing Record 21 of Set 2 | kerikeri
# Processing Record 22 of Set 2 | kodiak
# Processing Record 23 of Set 2 | tura
# Processing Record 24 of Set 2 | la ronge
# Processing Record 25 of Set 2 | puerto natales
# Processing Record 26 of Set 2 | tidjikja
# Processing Record 27 of Set 2 | ta`u
# Processing Record 28 of Set 2 | tiksi
# Processing Record 29 of Set 2 | edinburgh of the seven seas
# Processing Record 30 of Set 2 | bairnsdale
# Processing Record 31 of Set 2 | burang
# Processing Record 32 of Set 2 | fraserburgh
# Processing Record 33 of Set 2 | rabo de peixe
# Processing Record 34 of Set 2 | petrovsk-zabaykal'skiy
# Processing Record 35 of Set 2 | waitangi
# Processing Record 36 of Set 2 | newman
# Processing Record 37 of Set 2 | thanh hoa
# Processing Record 38 of Set 2 | alotau
# Processing Record 39 of Set 2 | saint simons island
# City not found. Skipping...
# Processing Record 40 of Set 2 | nuuk
# Processing Record 41 of Set 2 | puerto san carlos
# City not found. Skipping...
# Processing Record 42 of Set 2 | camalu
# Processing Record 43 of Set 2 | valle de la pascua
# Processing Record 44 of Set 2 | port douglas
# Processing Record 45 of Set 2 | porto novo
# Processing Record 46 of Set 2 | nova vicosa
# Processing Record 47 of Set 2 | sao jose da coroa grande
# Processing Record 48 of Set 2 | skutskar
# City not found. Skipping...
# Processing Record 49 of Set 2 | cabo san lucas
# Processing Record 0 of Set 3 | kyaikkami
# Processing Record 1 of Set 3 | cargados carajos
# City not found. Skipping...
# Processing Record 2 of Set 3 | papatowai
# Processing Record 3 of Set 3 | yuzhno-kurilsk
# Processing Record 4 of Set 3 | metro
# Processing Record 5 of Set 3 | port lincoln
# Processing Record 6 of Set 3 | alice springs
# Processing Record 7 of Set 3 | haiku-pauwela
# Processing Record 8 of Set 3 | ponta delgada
# Processing Record 9 of Set 3 | wailua homesteads
# Processing Record 10 of Set 3 | tuburan
# Processing Record 11 of Set 3 | yantarnyy
# Processing Record 12 of Set 3 | demba
# Processing Record 13 of Set 3 | phan rang-thap cham
# Processing Record 14 of Set 3 | ponneri
# Processing Record 15 of Set 3 | valparaiso
# Processing Record 16 of Set 3 | punta arenas
# Processing Record 17 of Set 3 | hithadhoo
# Processing Record 18 of Set 3 | sinop
# Processing Record 19 of Set 3 | nurota
# Processing Record 20 of Set 3 | zapolyarnyy
# Processing Record 21 of Set 3 | prado
# Processing Record 22 of Set 3 | ribeira grande
# Processing Record 23 of Set 3 | taiohae
# City not found. Skipping...
# Processing Record 24 of Set 3 | brush
# Processing Record 25 of Set 3 | howrah
# Processing Record 26 of Set 3 | lakshmeshwar
# Processing Record 27 of Set 3 | sierra grande
# Processing Record 28 of Set 3 | roma
# Processing Record 29 of Set 3 | mossel bay
# Processing Record 30 of Set 3 | jinghong
# Processing Record 31 of Set 3 | namibe
# Processing Record 32 of Set 3 | puerto ayora
# Processing Record 33 of Set 3 | papao
# Processing Record 34 of Set 3 | little cayman
# City not found. Skipping...
# Processing Record 35 of Set 3 | whitehorse
# Processing Record 36 of Set 3 | touros
# Processing Record 37 of Set 3 | imperatriz
# Processing Record 38 of Set 3 | arraial do cabo
# Processing Record 39 of Set 3 | st. john's
# Processing Record 40 of Set 3 | tolanaro
# Processing Record 41 of Set 3 | birine
# Processing Record 42 of Set 3 | qusmuryn
# Processing Record 43 of Set 3 | kulia village
# City not found. Skipping...
# Processing Record 44 of Set 3 | crucecita
# Processing Record 45 of Set 3 | dinguiraye
# Processing Record 46 of Set 3 | ajdabiya
# Processing Record 47 of Set 3 | hammerfest
# Processing Record 48 of Set 3 | lospalos
# Processing Record 49 of Set 3 | sola
# Processing Record 0 of Set 4 | bermejo
# Processing Record 1 of Set 4 | tangalle
# Processing Record 2 of Set 4 | bilibino
# Processing Record 3 of Set 4 | mindelo
# Processing Record 4 of Set 4 | tashir
# Processing Record 5 of Set 4 | bodaybo
# Processing Record 6 of Set 4 | new norfolk
# Processing Record 7 of Set 4 | flying fish cove
# Processing Record 8 of Set 4 | chui
# Processing Record 9 of Set 4 | kataragama
# City not found. Skipping...
# Processing Record 10 of Set 4 | severo-yeniseyskiy
# Processing Record 11 of Set 4 | lihue
# Processing Record 12 of Set 4 | quirinopolis
# Processing Record 13 of Set 4 | wuwei
# Processing Record 14 of Set 4 | petropavlovsk-kamchatsky
# Processing Record 15 of Set 4 | liwa
# Processing Record 16 of Set 4 | bhinmal
# Processing Record 17 of Set 4 | thompson
# Processing Record 18 of Set 4 | port alfred
# Processing Record 19 of Set 4 | nova sintra
# Processing Record 20 of Set 4 | gulf shores
# Processing Record 21 of Set 4 | chonchi
# Processing Record 22 of Set 4 | iquitos
# Processing Record 23 of Set 4 | maloye ganyushkino
# Processing Record 24 of Set 4 | la passe
# Processing Record 25 of Set 4 | khandyga
# Processing Record 26 of Set 4 | constantia
# Processing Record 27 of Set 4 | westport
# Processing Record 28 of Set 4 | usogorsk
# Processing Record 29 of Set 4 | gangneung
# Processing Record 30 of Set 4 | atafu village
# Processing Record 31 of Set 4 | keflavik
# Processing Record 32 of Set 4 | gazli
# Processing Record 33 of Set 4 | villa alberto andres alvarado aramburo
# City not found. Skipping...
# Processing Record 34 of Set 4 | kirsanov
# Processing Record 35 of Set 4 | naze
# Processing Record 36 of Set 4 | laguna
# Processing Record 37 of Set 4 | nizhneudinsk
# Processing Record 38 of Set 4 | sonsorol village
# City not found. Skipping...
# Processing Record 39 of Set 4 | bardai
# Processing Record 40 of Set 4 | rondonopolis
# Processing Record 41 of Set 4 | shiyan
# Processing Record 42 of Set 4 | vetluzhskiy
# Processing Record 43 of Set 4 | aldinga beach
# Processing Record 44 of Set 4 | kintinku
# Processing Record 45 of Set 4 | sisimiut
# Processing Record 46 of Set 4 | kapuskasing
# Processing Record 47 of Set 4 | mili
# Processing Record 48 of Set 4 | toga village
# City not found. Skipping...
# Processing Record 49 of Set 4 | bel ombre
# Processing Record 0 of Set 5 | vydrino
# Processing Record 1 of Set 5 | saipan
# Processing Record 2 of Set 5 | lebu
# Processing Record 3 of Set 5 | sechura
# Processing Record 4 of Set 5 | fale old settlement
# Processing Record 5 of Set 5 | fortuna
# Processing Record 6 of Set 5 | portage
# Processing Record 7 of Set 5 | trairi
# Processing Record 8 of Set 5 | port macquarie
# Processing Record 9 of Set 5 | taoudenni
# Processing Record 10 of Set 5 | nar'yan-mar
# Processing Record 11 of Set 5 | crane
# Processing Record 12 of Set 5 | codo
# Processing Record 13 of Set 5 | tynda
# Processing Record 14 of Set 5 | bubaque
# Processing Record 15 of Set 5 | el calafate
# Processing Record 16 of Set 5 | arsen'yev
# Processing Record 17 of Set 5 | swift current
# Processing Record 18 of Set 5 | mildura
# Processing Record 19 of Set 5 | mount isa
# Processing Record 20 of Set 5 | ierapetra
# Processing Record 21 of Set 5 | iskateley
# Processing Record 22 of Set 5 | saint-denis
# Processing Record 23 of Set 5 | fuvahmulah
# City not found. Skipping...
# Processing Record 24 of Set 5 | hadibu
# Processing Record 25 of Set 5 | priob'ye
# Processing Record 26 of Set 5 | labrador city
# Processing Record 27 of Set 5 | afaahiti
# Processing Record 28 of Set 5 | college
# Processing Record 29 of Set 5 | oranjemund
# Processing Record 30 of Set 5 | bonthe
# Processing Record 31 of Set 5 | tsetserleg
# Processing Record 32 of Set 5 | isla del bosque
# Processing Record 33 of Set 5 | usinsk
# Processing Record 34 of Set 5 | gamba
# Processing Record 35 of Set 5 | zhangatas
# Processing Record 36 of Set 5 | prokuplje
# Processing Record 37 of Set 5 | okondja
# Processing Record 38 of Set 5 | guidel-plage
# Processing Record 39 of Set 5 | geraldton
# Processing Record 40 of Set 5 | lata
# Processing Record 41 of Set 5 | ilhabela
# Processing Record 42 of Set 5 | yerofey pavlovich
# Processing Record 43 of Set 5 | general ramirez
# Processing Record 44 of Set 5 | kirakira
# Processing Record 45 of Set 5 | san antonio del estrecho
# City not found. Skipping...
# Processing Record 46 of Set 5 | dahab
# Processing Record 47 of Set 5 | ulsteinvik
# Processing Record 48 of Set 5 | pibor
# City not found. Skipping...
# Processing Record 49 of Set 5 | east london
# Processing Record 0 of Set 6 | kapa'a
# Processing Record 1 of Set 6 | colares
# Processing Record 2 of Set 6 | nouadhibou
# Processing Record 3 of Set 6 | lompoc
# Processing Record 4 of Set 6 | sandnessjoen
# Processing Record 5 of Set 6 | kavieng
# Processing Record 6 of Set 6 | yagry
# City not found. Skipping...
# Processing Record 7 of Set 6 | tazovsky
# Processing Record 8 of Set 6 | drobeta-turnu severin
# Processing Record 9 of Set 6 | el daein
# City not found. Skipping...
# Processing Record 10 of Set 6 | grand falls-windsor
# Processing Record 11 of Set 6 | kaoma
# Processing Record 12 of Set 6 | las khorey
# Processing Record 13 of Set 6 | hamilton
# Processing Record 14 of Set 6 | el nido
# Processing Record 15 of Set 6 | anadyr
# Processing Record 16 of Set 6 | aykhal
# Processing Record 17 of Set 6 | longyearbyen
# Processing Record 18 of Set 6 | carnarvon
# Processing Record 19 of Set 6 | hasaki
# Processing Record 20 of Set 6 | ust-nera
# Processing Record 21 of Set 6 | happy valley-goose bay
# Processing Record 22 of Set 6 | tabou
# Processing Record 23 of Set 6 | argo
# Processing Record 24 of Set 6 | howard springs
# Processing Record 25 of Set 6 | mil'kovo
# Processing Record 26 of Set 6 | mount gambier
# Processing Record 27 of Set 6 | inarajan village
# Processing Record 28 of Set 6 | kroya
# Processing Record 29 of Set 6 | emerald
# Processing Record 30 of Set 6 | nemuro
# Processing Record 31 of Set 6 | nogliki
# Processing Record 32 of Set 6 | itaituba
# Processing Record 33 of Set 6 | buala
# Processing Record 34 of Set 6 | rio claro
# Processing Record 35 of Set 6 | tofol
# Processing Record 36 of Set 6 | constitucion
# Processing Record 37 of Set 6 | kingston
# Processing Record 38 of Set 6 | nuku'alofa
# Processing Record 39 of Set 6 | dampit
# Processing Record 40 of Set 6 | prince rupert
# Processing Record 41 of Set 6 | nantucket
# Processing Record 42 of Set 6 | calvinia
# Processing Record 43 of Set 6 | fort mcmurray
# Processing Record 44 of Set 6 | daru
# Processing Record 45 of Set 6 | nadym
# Processing Record 46 of Set 6 | adigrat
# Processing Record 47 of Set 6 | shakawe
# Processing Record 48 of Set 6 | kisasa
# City not found. Skipping...
# Processing Record 49 of Set 6 | salalah
# Processing Record 0 of Set 7 | hami
# Processing Record 1 of Set 7 | margate
# Processing Record 2 of Set 7 | antonio enes
# Processing Record 3 of Set 7 | krasnik
# Processing Record 4 of Set 7 | acapulco de juarez
# Processing Record 5 of Set 7 | goundam
# Processing Record 6 of Set 7 | zhanaozen
# Processing Record 7 of Set 7 | rio grande
# Processing Record 8 of Set 7 | enewetak
# Processing Record 9 of Set 7 | xiaoweizhai
# Processing Record 10 of Set 7 | aasiaat
# Processing Record 11 of Set 7 | durant
# Processing Record 12 of Set 7 | paita
# Processing Record 13 of Set 7 | san patricio
# Processing Record 14 of Set 7 | tshela
# Processing Record 15 of Set 7 | forster
# Processing Record 16 of Set 7 | rongelap
# Processing Record 17 of Set 7 | okhotsk
# Processing Record 18 of Set 7 | villa bruzual
# Processing Record 19 of Set 7 | tyuratam
# Processing Record 20 of Set 7 | cidade velha
# Processing Record 21 of Set 7 | mirny
# Processing Record 22 of Set 7 | akobo
# Processing Record 23 of Set 7 | richlands
# Processing Record 24 of Set 7 | champerico
# Processing Record 25 of Set 7 | darnah
# Processing Record 26 of Set 7 | labuan lombok
# City not found. Skipping...
# Processing Record 27 of Set 7 | gadzhiyevo
# Processing Record 28 of Set 7 | lembar
# City not found. Skipping...
# Processing Record 29 of Set 7 | port mathurin
# Processing Record 30 of Set 7 | nueva guinea
# Processing Record 31 of Set 7 | nueva concepcion
# Processing Record 32 of Set 7 | vingt cinq
# City not found. Skipping...
# Processing Record 33 of Set 7 | haapsalu
# Processing Record 34 of Set 7 | puerto ayacucho
# Processing Record 35 of Set 7 | al qubbah
# Processing Record 36 of Set 7 | pemba
# Processing Record 37 of Set 7 | copala
# Processing Record 38 of Set 7 | alaghsas
# Processing Record 39 of Set 7 | 'ohonua
# City not found. Skipping...
# Processing Record 40 of Set 7 | nanning
# Processing Record 41 of Set 7 | el sauzal de rodriguez
# Processing Record 42 of Set 7 | lorengau
# Processing Record 43 of Set 7 | bamboo flat
# Processing Record 44 of Set 7 | utrik
# Processing Record 45 of Set 7 | omutinskiy
# Processing Record 46 of Set 7 | west island
# Processing Record 47 of Set 7 | hanamaki
# Processing Record 48 of Set 7 | la sarre
# Processing Record 49 of Set 7 | castillos
# Processing Record 0 of Set 8 | boyolangu
# Processing Record 1 of Set 8 | al kharj
# Processing Record 2 of Set 8 | paredon
# Processing Record 3 of Set 8 | morondava
# Processing Record 4 of Set 8 | isangel
# Processing Record 5 of Set 8 | ihosy
# Processing Record 6 of Set 8 | sakaiminato
# Processing Record 7 of Set 8 | kununurra
# Processing Record 8 of Set 8 | dakhla
# Processing Record 9 of Set 8 | domene
# Processing Record 10 of Set 8 | monkey bay
# Processing Record 11 of Set 8 | quezon
# Processing Record 12 of Set 8 | swakopmund
# Processing Record 13 of Set 8 | arta
# Processing Record 14 of Set 8 | pauini
# Processing Record 15 of Set 8 | kayangel
# Processing Record 16 of Set 8 | vilyuysk
# Processing Record 17 of Set 8 | minas de marcona
# Processing Record 18 of Set 8 | fort riley north
# Processing Record 19 of Set 8 | hadithah
# Processing Record 20 of Set 8 | puerto baquerizo moreno
# Processing Record 21 of Set 8 | tromso
# Processing Record 22 of Set 8 | enoch
# Processing Record 23 of Set 8 | hilo
# Processing Record 24 of Set 8 | sovetskaya gavan'
# Processing Record 25 of Set 8 | san luis de la loma
# Processing Record 26 of Set 8 | vilyuchinsk
# Processing Record 27 of Set 8 | gaigeturi
# Processing Record 28 of Set 8 | tataouine
# Processing Record 29 of Set 8 | parambu
# Processing Record 30 of Set 8 | vernon
# Processing Record 31 of Set 8 | altamont
# Processing Record 32 of Set 8 | seven pagodas
# Processing Record 33 of Set 8 | egilsstadir
# Processing Record 34 of Set 8 | kyjov
# Processing Record 35 of Set 8 | kristiansund
# Processing Record 36 of Set 8 | rada tilly
# Processing Record 37 of Set 8 | lib
# Processing Record 38 of Set 8 | bac lieu
# Processing Record 39 of Set 8 | murashi
# Processing Record 40 of Set 8 | novoorsk
# Processing Record 41 of Set 8 | slave lake
# Processing Record 42 of Set 8 | kendari
# Processing Record 43 of Set 8 | apolinario saravia
# Processing Record 44 of Set 8 | itarantim
# Processing Record 45 of Set 8 | rach gia
# Processing Record 46 of Set 8 | san antonio de pale
# Processing Record 47 of Set 8 | pingxiang
# Processing Record 48 of Set 8 | saint-felix-de-valois
# Processing Record 49 of Set 8 | pariaman
# Processing Record 0 of Set 9 | pacific grove
# Processing Record 1 of Set 9 | wewak
# Processing Record 2 of Set 9 | ahau
# City not found. Skipping...
# Processing Record 3 of Set 9 | uturoa
# Processing Record 4 of Set 9 | thinadhoo
# Processing Record 5 of Set 9 | vorgashor
# Processing Record 6 of Set 9 | gizo
# Processing Record 7 of Set 9 | rengasdengklok
# Processing Record 8 of Set 9 | banda aceh
# Processing Record 9 of Set 9 | lobito
# Processing Record 10 of Set 9 | colonia
# Processing Record 11 of Set 9 | colonia menno
# Processing Record 12 of Set 9 | port-gentil
# Processing Record 13 of Set 9 | cable beach
# City not found. Skipping...
# Processing Record 14 of Set 9 | mhamid
# Processing Record 15 of Set 9 | zharkent
# Processing Record 16 of Set 9 | george town
# Processing Record 17 of Set 9 | khilok
# Processing Record 18 of Set 9 | madras
# Processing Record 19 of Set 9 | onchan
# Processing Record 20 of Set 9 | luderitz
# Processing Record 21 of Set 9 | pont rouge
# Processing Record 22 of Set 9 | ostersund
# Processing Record 23 of Set 9 | al azraq ash shamali
# City not found. Skipping...
# Processing Record 24 of Set 9 | bowral
# Processing Record 25 of Set 9 | cockburn town
# Processing Record 26 of Set 9 | lucapa
# Processing Record 27 of Set 9 | nagqu
# Processing Record 28 of Set 9 | kiruna
# Processing Record 29 of Set 9 | bonnyville
# Processing Record 30 of Set 9 | carahue
# Processing Record 31 of Set 9 | north bend
# Processing Record 32 of Set 9 | luanda
# Processing Record 33 of Set 9 | masvingo
# Processing Record 34 of Set 9 | lerwick
# Processing Record 35 of Set 9 | opuwo
# Processing Record 36 of Set 9 | zagora
# Processing Record 37 of Set 9 | guider
# Processing Record 38 of Set 9 | sao felix do xingu
# Processing Record 39 of Set 9 | kamoke
# Processing Record 40 of Set 9 | nea alikarnassos
# Processing Record 41 of Set 9 | san pedro
# Processing Record 42 of Set 9 | tralee
# Processing Record 43 of Set 9 | bridgewater
# Processing Record 44 of Set 9 | la'ie
# Processing Record 45 of Set 9 | murmashi
# Processing Record 46 of Set 9 | bra
# Processing Record 47 of Set 9 | smithers
# Processing Record 48 of Set 9 | polyarnyy
# Processing Record 49 of Set 9 | cidreira
# Processing Record 0 of Set 10 | katsuren-haebaru
# Processing Record 1 of Set 10 | lazaro cardenas
# Processing Record 2 of Set 10 | debark'
# Processing Record 3 of Set 10 | afif
# Processing Record 4 of Set 10 | zouerate
# Processing Record 5 of Set 10 | jega
# Processing Record 6 of Set 10 | kismayo
# Processing Record 7 of Set 10 | mikuni
# Processing Record 8 of Set 10 | bushehr
# Processing Record 9 of Set 10 | khash
# Processing Record 10 of Set 10 | richfield
# Processing Record 11 of Set 10 | chibougamau
# Processing Record 12 of Set 10 | waingapu
# Processing Record 13 of Set 10 | kourou
# Processing Record 14 of Set 10 | jwaneng
# Processing Record 15 of Set 10 | murghob
# Processing Record 16 of Set 10 | guinticgan
# Processing Record 17 of Set 10 | almeirim
# Processing Record 18 of Set 10 | tsiombe
# Processing Record 19 of Set 10 | parapat
# Processing Record 20 of Set 10 | aqadyr
# Processing Record 21 of Set 10 | saint-louis
# Processing Record 22 of Set 10 | bengkulu
# Processing Record 23 of Set 10 | lijiang
# Processing Record 24 of Set 10 | maputo
# Processing Record 25 of Set 10 | vadso
# Processing Record 26 of Set 10 | kongsvinger
# Processing Record 27 of Set 10 | ambon
# Processing Record 28 of Set 10 | taksimo
# Processing Record 29 of Set 10 | saint-philippe
# Processing Record 30 of Set 10 | illizi
# Processing Record 31 of Set 10 | valozhyn
# Processing Record 32 of Set 10 | gao
# Processing Record 33 of Set 10 | puerto cortez
# Processing Record 34 of Set 10 | batroun
# Processing Record 35 of Set 10 | gwanda
# Processing Record 36 of Set 10 | portland
# Processing Record 37 of Set 10 | kutum
# Processing Record 38 of Set 10 | jose mariano jimenez
# City not found. Skipping...
# Processing Record 39 of Set 10 | albertina
# Processing Record 40 of Set 10 | olyokminsk
# Processing Record 41 of Set 10 | nelidovo
# Processing Record 42 of Set 10 | goroka
# Processing Record 43 of Set 10 | kamina
# Processing Record 44 of Set 10 | envira
# Processing Record 45 of Set 10 | timbuktu
# Processing Record 46 of Set 10 | tarinkot
# Processing Record 47 of Set 10 | nasiriyah
# Processing Record 48 of Set 10 | camas
# Processing Record 49 of Set 10 | marion
# Processing Record 0 of Set 11 | tirhanimine
# Processing Record 1 of Set 11 | villa gesell
# Processing Record 2 of Set 11 | yingkou
# Processing Record 3 of Set 11 | vertientes
# Processing Record 4 of Set 11 | lincheng
# Processing Record 5 of Set 11 | sao vicente
# Processing Record 6 of Set 11 | yanam
# Processing Record 7 of Set 11 | xai-xai
# Processing Record 8 of Set 11 | fort st. john
# Processing Record 9 of Set 11 | petrosino
# Processing Record 10 of Set 11 | ghat
# Processing Record 11 of Set 11 | ocean shores
# Processing Record 12 of Set 11 | sosnovka
# Processing Record 13 of Set 11 | san jose del cabo
# Processing Record 14 of Set 11 | road town
# Processing Record 15 of Set 11 | nizhniy kuranakh
# Processing Record 16 of Set 11 | tranovaho
# City not found. Skipping...
# Processing Record 17 of Set 11 | kirksville
# Processing Record 18 of Set 11 | santa sylvina
# Processing Record 19 of Set 11 | misratah
# Processing Record 20 of Set 11 | mount pearl
# Processing Record 21 of Set 11 | souillac
# Processing Record 22 of Set 11 | berezovyy
# Processing Record 23 of Set 11 | mandal
# Processing Record 24 of Set 11 | susanville
# Processing Record 25 of Set 11 | naracoorte
# Processing Record 26 of Set 11 | grande prairie
# Processing Record 27 of Set 11 | antsiranana
# Processing Record 28 of Set 11 | bayan nur
# City not found. Skipping...
# Processing Record 29 of Set 11 | kyshtovka
# Processing Record 30 of Set 11 | kanoya
# Processing Record 31 of Set 11 | bathsheba
# Processing Record 32 of Set 11 | kailua-kona
# Processing Record 33 of Set 11 | doba
# Processing Record 34 of Set 11 | villafranca tirrena
# Processing Record 35 of Set 11 | harrisonville
# Processing Record 36 of Set 11 | nakonde
# Processing Record 37 of Set 11 | eisenach
# Processing Record 38 of Set 11 | wundanyi
# Processing Record 39 of Set 11 | idri
# Processing Record 40 of Set 11 | patterson
# Processing Record 41 of Set 11 | khulm
# Processing Record 42 of Set 11 | suphan buri
# Processing Record 43 of Set 11 | sanctuary point
# Processing Record 44 of Set 11 | tateyama
# Processing Record 45 of Set 11 | okakarara
# Processing Record 46 of Set 11 | gallivare
# City not found. Skipping...
# Processing Record 47 of Set 11 | tazacorte
# Processing Record 48 of Set 11 | chela
# Processing Record 49 of Set 11 | angaur state
# Processing Record 0 of Set 12 | kouroussa
# Processing Record 1 of Set 12 | mar del plata
# Processing Record 2 of Set 12 | kiunga
# Processing Record 3 of Set 12 | boa vista
# Processing Record 4 of Set 12 | arawa
# Processing Record 5 of Set 12 | porto feliz
# Processing Record 6 of Set 12 | piti village
# Processing Record 7 of Set 12 | qarazhal
# Processing Record 8 of Set 12 | karratha
# Processing Record 9 of Set 12 | luwuk
# Processing Record 10 of Set 12 | chapeco
# Processing Record 11 of Set 12 | midvagur
# Processing Record 12 of Set 12 | ridder
# Processing Record 13 of Set 12 | galesong
# Processing Record 14 of Set 12 | galliano
# Processing Record 15 of Set 12 | pacocha
# Processing Record 16 of Set 12 | xilin hot
# Processing Record 17 of Set 12 | new plymouth
# Processing Record 18 of Set 12 | montepuez
# Processing Record 19 of Set 12 | beyneu
# Processing Record 20 of Set 12 | arkhara
# Processing Record 21 of Set 12 | adjumani
# Processing Record 22 of Set 12 | justo daract
# Processing Record 23 of Set 12 | puerto cabezas
# Processing Record 24 of Set 12 | cukai
# Processing Record 25 of Set 12 | vangaindrano
# Processing Record 26 of Set 12 | lashio
# Processing Record 27 of Set 12 | vila franca do campo
# Processing Record 28 of Set 12 | puerto santa
# Processing Record 29 of Set 12 | dryden
# Processing Record 30 of Set 12 | pago pago
# Processing Record 31 of Set 12 | inirida
# Processing Record 32 of Set 12 | ampanihy
# Processing Record 33 of Set 12 | broken hill
# Processing Record 34 of Set 12 | sohna
# Processing Record 35 of Set 12 | ibshaway
# Processing Record 36 of Set 12 | tarawa
# Processing Record 37 of Set 12 | odda
# Processing Record 38 of Set 12 | mercedes
# Processing Record 39 of Set 12 | auki
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
 # Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

city_data_df.to_csv(output_data_file, index_label="City_ID")

# Display sample data
city_data_df.count()
# Out:
# City          561
# Lat           561
# Lng           561
# Max Temp      561
# Humidity      561
# Cloudiness    561
# Wind Speed    561
# Country       561
# Date          561
# dtype: int64

# %%
# Export the City_Data into a csv
city_data_df.to_csv("Starter_Code/output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("Starter_Code/output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                vodnyy  63.5046   53.4095     37.63        85          90
# 1        margaret river -33.9500  115.0667     60.78        57           8
# 2               iqaluit  63.7506  -68.5145     33.53        86         100
# 3            walvis bay -22.9575   14.5053     50.95        93           0
# 4               tuy hoa  13.0833  109.3000     83.50        74          96
#
#          Wind Speed Country        Date
# City_ID
# 0              6.31      RU  1729130090
# 1              9.95      AU  1729130091
# 2             16.11      CA  1729130092
# 3              6.91     NaN  1729130093
# 4              3.00      VN  1729130094

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature

lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]


plt.scatter(lats,
           max_temps,
           edgecolor="black", linewidth=1, marker="o",
           alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude Vs. Max Temperature(%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Starter_Code/output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(lats,
            humidity,
           edgecolor="black", linewidth=1, marker="o",
           alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude Vs. Humidity(%s)" % time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Starter_Code/output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(lats,
            cloudiness,
           edgecolor="black", linewidth=1, marker="o",
           alpha=0.8, label="Cities")


# Incorporate the other graph properties
plt.title("City Latitude Vs. Cloudiness(%s)" % time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Starter_Code/output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(lats,
            wind_speed,
           edgecolor="black", linewidth=1, marker="o",
           alpha=0.8, label="Cities")


# Incorporate the other graph properties
plt.title("City Latitude Vs. Wind Speed(%s)" % time.strftime("%x"))
plt.ylabel("Windspeed mph")
plt.xlabel("Latitude")
plt.grid(True)


# Save the figure
plt.savefig("Starter_Code/output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values,y_values,title,text_coordinates):
    
    # Run regression on Southern Hemisphere
    (slope, intercept, rvalue, pvalue, stderr) = linregress (x_values,y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + " x + " + str(round(intercept,2))
    
    # Plot
    plt.scatter(x_values,y_values)
    plt.plot(x_values, regress_values, "r-")
    plt.annotate(line_eq,text_coordinates, fontsize=15, color="red")
    plt.xlabel("Latitude")
    plt.ylabel("Title")
    print(f"The r-squared is: {rvalue}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]


# Display sample data
northern_hemi_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          vodnyy  63.5046   53.4095     37.63        85          90
# 2         iqaluit  63.7506  -68.5145     33.53        86         100
# 4         tuy hoa  13.0833  109.3000     83.50        74          96
# 5         udachny  66.4167  112.4000      9.05        92          97
# 7        qaqortoq  60.7167  -46.0333     31.28        54         100
#
#          Wind Speed Country        Date
# City_ID
# 0              6.31      RU  1729130090
# 2             16.11      CA  1729130092
# 4              3.00      VN  1729130094
# 5             11.10      RU  1729130096
# 7              8.68      GL  1729130099

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] <0)]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1           margaret river -33.9500  115.0667     60.78        57           8
# 3               walvis bay -22.9575   14.5053     50.95        93           0
# 6               bredasdorp -34.5322   20.0403     56.25        85          10
# 8                 saldanha -33.0117   17.9442     57.25        96           6
# 10       port-aux-francais -49.3500   70.2167     35.65        92          97
#
#          Wind Speed Country        Date
# City_ID
# 1              9.95      AU  1729130091
# 3              6.91     NaN  1729130093
# 6              7.72      ZA  1729130098
# 8              7.99      ZA  1729130100
# 10            22.24      TF  1729130102

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df ["Lat"]
y_values = northern_hemi_df ["Max Temp"]
plot_linear_regression(x_values,y_values, 'Max Temp', (6,30))
# Out:
# The r-squared is: -0.8716494295345476

# %%
# Linear regression on Southern Hemisphere

x_values = southern_hemi_df ["Lat"]
y_values = southern_hemi_df ["Max Temp"]
plot_linear_regression(x_values,y_values, 'Max Temp', (-30,40))
# Out:
# The r-squared is: 0.6429563305249169

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df ["Lat"]
y_values = northern_hemi_df ["Humidity"]
plot_linear_regression(x_values,y_values, 'Humidity', (40,10))
# Out:
# The r-squared is: 0.1156401261550029

# %%
# Southern Hemisphere

x_values = southern_hemi_df ["Lat"]
y_values = southern_hemi_df ["Humidity"]
plot_linear_regression(x_values,y_values, 'Humidity', (-30,150))
# Out:
# The r-squared is: 0.00557320306359018

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df ["Lat"]
y_values = northern_hemi_df ["Cloudiness"]
plot_linear_regression(x_values,y_values, 'Cloudiness', (40,10))
# Out:
# The r-squared is: 0.14387923865959176

# %%
# Southern Hemisphere
x_values = southern_hemi_df ["Lat"]
y_values = southern_hemi_df ["Cloudiness"]
plot_linear_regression(x_values,y_values, 'Cloudiness', (-30,30))
# Out:
# The r-squared is: 0.09584000145205457

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df ["Lat"]
y_values = northern_hemi_df ["Wind Speed"]
plot_linear_regression(x_values,y_values, 'Wind Speed', (40,25))
# Out:
# The r-squared is: 0.1749675536445393

# %%
# Southern Hemisphere
x_values = southern_hemi_df ["Lat"]
y_values = southern_hemi_df ["Wind Speed"]
plot_linear_regression(x_values,y_values, 'Wind Speed', (-30,30))
# Out:
# The r-squared is: -0.20153973926180527

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
